# %%
# %matplotlib inline 

from sklearn.externals import joblib
x_train, x_test, y_train, y_test = joblib.load('dataset.pkl')

clf = joblib.load('svm_model.pkl')

import numpy as np
import matplotlib.pyplot as plt

clf.predict([x_train[0]])

import os    
files = os.listdir('patterns')

def pattern(index):
    import scipy.misc
    
    if (index >= len(files)):
        return np.ones((64,64))
    
    return scipy.misc.imread('patterns/' + files[index], flatten=True)/255

count = 0

for x,y in zip( x_test,  y_test):
    predicted = clf.predict([x])
    
    if predicted != [y]:
        count += 1
        
        plt.imshow(np.concatenate((x.reshape(64,64), pattern(predicted[0]), pattern(y)), axis=1))
        plt.figure()
        
plt.show()

(len(x_test) - count) /len(x_test)
# Out:
# /home/mihai/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# 0.975531914893617
