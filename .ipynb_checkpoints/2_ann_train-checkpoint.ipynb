# %%
from sklearn.externals import joblib
x_train, x_test, y_train, y_test = joblib.load('dataset.pkl')

from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier

tuned_parameters = [{'activation':['relu','logistic'], 
                     'learning_rate_init':[1, 0.1, 0.01, 0.001],
                     'momentum':[0.5, 0.9]}]

clf = GridSearchCV(MLPClassifier(), tuned_parameters, verbose=True, n_jobs=4)
clf.fit(x_train, y_train)

from sklearn.externals import joblib
joblib.dump(clf, 'ann_model.pkl')
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [Parallel(n_jobs=8)]: Done  48 out of  48 | elapsed: 14.1min finished
# ['ann_model.pkl']
